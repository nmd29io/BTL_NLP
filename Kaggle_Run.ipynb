# %% [markdown]
# # Training Transformer for Vi-En Translation on Kaggle
#
# This notebook automates the process of cloning the repository, installing dependencies, training the model, and evaluating it on Kaggle.

# %%
# 1. Setup Environment & Clone Repo
import os

WORKING_DIR = '/kaggle/working'
REPO_DIR = os.path.join(WORKING_DIR, 'BTL_NLP')

if not os.path.exists(REPO_DIR):
    # !git clone https://github.com/nmd29io/BTL_NLP.git $REPO_DIR
else:
    print("Repository already exists. Pulling latest changes...")
    # %cd $REPO_DIR
    # !git pull

# %cd $REPO_DIR

# %%
# 2. Install dependencies
# !pip install -r requirements.txt

# %%
# 3. Train the model (Save to Kaggle Output)
# We explicitly set the directories to /kaggle/working to ensure artifacts are saved in the output section
# !python train.py --max_time_hours 2.0 --model_dir "/kaggle/working/models" --results_dir "/kaggle/working/results"

# %%
# 4. Evaluate the model
# !python evaluate.py --model_path "/kaggle/working/models/best_model.pt" --results_dir "/kaggle/working/results"

# %%
# 5. Create Zip for Download
# Kaggle allows downloading files from the Output tab, but zipping makes it easier
# %cd /kaggle/working
# !zip -r experiment_results.zip models/ results/
print("Success! You can download 'experiment_results.zip' from the Output tab.")
